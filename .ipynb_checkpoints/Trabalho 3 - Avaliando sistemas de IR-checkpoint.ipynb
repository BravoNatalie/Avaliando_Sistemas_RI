# %% [markdown]
# # Trabalho 3: Avaliando sistemas de IR
#
# Neste trabalho, o aluno irá explorar o problema de otimização de sistemas de IR através da análise de métricas de avaliação populares para esse tipo de sistema.
#
# Para isso, vamos usar a base CFC (com artigos sobre fibrose cística), a qual encontra-se nesta pasta.
#
# Observação: a idéia aqui é usar o jupyter para mostrar a evolução dos teus experimentos. Então use ele adequadamente. Ou seja, não altere funções do começo para reexecutar algo que foi feito lá embaixo. Neste caso, sobreescreva a função lá embaixo. A leitura do notebook tem que ser feita sequencialmente para ficar fácil, ok?
#
#
# ## Passo 1 - Normalização
#
# Primeira coisa que você vai precisar fazer é ler os arquivos do CFC. Essa é uma parte meio braçal mesmo, mas não tem como escapar dela. Então você terá que criar funções que consigam ler cada arquivo do CFC e parsear eles.

# %%
#import ipdb;ipdb.set_trace()

import pandas as pd
import json

FILES = ['cfc/cf74', 'cfc/cf75', 'cfc/cf76', 'cfc/cf77', 'cfc/cf78', 'cfc/cf79']
col = ['PN', 'RN', 'AN', 'AU', 'TI', 'SO', 'MJ', 'MN', 'AB/EX', 'RF', 'CT']
matrixTotal = []

def insert(i, value, vector):
    if(len(vector) <= i):
        vector.insert(i,value)
    else:
        vector[i] += ' ' + value


def constructVector(vector, line, cod):  
    if(cod == 'PN'): # PAPER NUMBER
        insert(0, line[3:], vector)
        
    elif(cod == 'RN'): # RECORD NUMBER
        insert(1, line[3:], vector)
        
    elif(cod == 'AN'): #  MEDLINE ACESSION NUMBER
        insert(2, line[3:], vector)
        
    elif(cod == 'AU'): # AUTHOR(S)
        insert(3, line[3:], vector)

    elif(cod == 'TI'): # TITLE
        insert(4, line[3:], vector)
        
    elif(cod == 'SO'): # SOURCE
        insert(5, line[3:], vector)
        
    elif(cod == 'MJ'): # MAJOR SUBJECTS
        insert(6, line[3:], vector)
    
    elif(cod == 'MN'): # MINOR SUBJECTS
        insert(7, line[3:], vector)
        
    elif((cod == 'AB') or (cod == 'EX')): # ABSTRACT/EXTRACT
        insert(8, line[3:], vector)
        
    elif(cod == 'RF'): # REFERENCES
        insert(9, line[3:], vector)
        
    elif(cod == 'CT'): # CITATIONS
        insert(10, line[3:], vector)
    else:
        pass
    

def fileToMatrix(file):
    matrix = []
    with open(file, 'r', encoding = 'iso-8859-1') as fp:
        vector = []
        line = fp.readline()
        cod = line[:2]
        constructVector(vector, line.strip().replace("  ", ""), cod)

        while line:
            line = fp.readline()
            if not((line[:2]).isspace()):
                cod = line[:2]
            if((line == "\n") and (len(vector) > 2)):
                matrix.append(vector)
                vector = []
            constructVector(vector, line.strip().replace("  ", ""), cod)    
    
    fp.close()
    return matrix

        
for file in FILES:
    matrixTotal.extend(fileToMatrix(file))  
    
    
pd.DataFrame(matrixTotal, columns=col)    

#m = fileToMatrix('cfc/cf74')
# Out:
#           PN     RN        AN  \
# 0      74001  00001  75051687
# 1      74002  00002  74260154
# 2      74003  00003  74252221
# 3      74004  00004  74252220
# 4      74005  00005  75051680
# 5      74006  00006  75014083
# 6      74007  00007  75014084
# 7      74008  00008  75009735
# 8      74009  00009  74087894
# 9      74010  00010  74154352
# 10     74011  00011  75008123
# 11     74012  00012  74154356
# 12     74013  00013  74074555
# 13     74014  00014  74103902
# 14     74015  00015  74129630
# 15     74016  00016  74107099
# 16     74017  00017  75144214
# 17     74018  00018  74109137
# 18     74019  00019  75012012
# 19     74020  00020  74146275
# 20     74021  00021  75052992
# 21     74022  00022  74122409
# 22     74023  00023  75010757
# 23     74024  00024  74091941
# 24     74025  00025  75071389
# 25     74026  00026  74109135
# 26     74027  00027  75071396
# 27     74028  00028  75053321
# 28     74029  00029  74124785
# 29     74030  00030  74154485
# ...      ...    ...       ...
# 1209   79230  01210  80055672
# 1210   79231  01211  80055673
# 1211   79232  01212  80012528
# 1212   79233  01213  79246210
# 1213   79234  01214  79179506
# 1214   79235  01215  79200786
# 1215   79236  01216  79179608
# 1216   79237  01217  79179561
# 1217   79238  01218  79200748
# 1218   79239  01219  80012602
# 1219   79240  01220  80146088
# 1220   79241  01221  79180081
# 1221   79242  01222  79223914
# 1222   79243  01223  80122681
# 1223   79244  01224  80122682
# 1224   79245  01225  80080576
# 1225   79246  01226  81015715
# 1226   79247  01227  80103180
# 1227   79248  01228  79181690
# 1228   79249  01229  79181691
# 1229   79250  01230  80081508
# 1230   79251  01231  79138718
# 1231   79252  01232  80036401
# 1232   79253  01233  79181843
# 1233   79254  01234  79138906
# 1234   79255  01235  80014930
# 1235   79256  01236  80124640
# 1236   79257  01237  80015007
# 1237   79258  01238  80237415
# 1238   79259  01239  80105142
#
#                                                      AU  \
# 0     Hoiby-N.Jacobsen-L.Jorgensen-B-A.Lykkegaard-E....
# 1        Rossiter-M-A.Barrowman-J-A.Dand-A.Wharton-B-A.
# 2                                  Kollberg-H.Ekbohm-G.
# 3                               Kollberg-H.Landstrom-O.
# 4                                           Lindberg-T.
# 5                                  Hoiby-N.Mathiesen-L.
# 6                                              Hoiby-N.
# 7                                              Hoiby-N.
# 8                 Franklin-J-L.Asquith-P.Rosenberg-I-H.
# 9                            Burnell-R-H.Robertson-E-F.
# 10    Rachelefsky-G-S.Osher-A.Dooley-R-E.Ank-B.Stieh...
# 11                                   Fluge-G.Aarskog-D.
# 12                              Kulczycki-L-L.Schauf-V.
# 13                    Burton-B-K.Gerbie-A-B.Nadler-H-L.
# 14                   Dooley-R-R.Braunstein-H.Osher-A-B.
# 15                                         Ozonoff-M-B.
# 16                           Schwartz-E-E.Holsclaw-D-S.
# 17                        Biggar-W-D.Holmes-B.Good-R-A.
# 18                  Coburn-M-D.Coburn-L-A.Solomons-C-C.
# 19    Cooper-D-M.Doron-I.Mansell-A-L.Bryan-A-C.Levis...
# 20                               Dolan-T-F-Jr.Meyers-A.
# 21                Doershuk-C-F.Fisher-B-J.Matthews-L-W.
# 22    Boat-T-F.Kleinerman-J-I.Carlson-D-M.Maloney-W-...
# 23    Mansell-A.Dubrawsky-C.Levison-H.Bryan-A-C.Croz...
# 24                                          Gibson-L-E.
# 25                                         Lieberman-J.
# 26                                         Mellins-R-B.
# 27                                Savory-J.Leitner-S-S.
# 28                         Taylor-B.Evans-J-N.Hope-G-A.
# 29                                             Levin-S.
# ...                                                 ...
# 1209           Tully-G-W.Nevin-G-B.Young-I-R.Nevin-N-C.
# 1210                                        Wilson-G-B.
# 1211                      Nagy-E-C.Khan-S.Sturgess-J-M.
# 1212                  Chase-H-P.Cotton-E-K.Elliott-R-B.
# 1213            Brasfield-D.Hicks-G.Soong-S.Tiller-R-E.
# 1214   Lloyd-Still-J-D.Simon-S-H.Wessel-H-U.Gibson-L-E.
# 1215                         Beckerman-R-C.Taussig-L-M.
# 1216                                 Nezelof-C.LeSec-G.
# 1217                                        Phelps-D-L.
# 1218                                     Beckerman-R-C.
# 1219                              Pryor-J-A.Webber-B-A.
# 1220     Martodam-R-R.Baugh-R-J.Twumasi-D-Y.Liener-I-E.
# 1221                    Shapiro-B-L.Feigal-R-J.Lam-L-F.
# 1222                                        Mangos-J-A.
# 1223                          Gluckson-M-M.Denning-C-R.
# 1224  New test to detect carriers of gene for cystic...
# 1225                             Swan-H-A.Chappell-J-S.
# 1226                                           Friis-B.
# 1227  Gawel-J.Rudnik-J.Pryjma-J.Zebrak-J.Hauszka-J.R...
# 1228        Zebrak-J.Herman-T.Werys-R.Pryjma-J.Gawel-J.
# 1229                   Kurz-J-B.Perkins-J-P.Buchwald-M.
# 1230                      Shapiro-B-L.Lam-L-F.Fast-L-H.
# 1231                               Howie-A-D.Stack-B-H.
# 1232                                       Frydman-M-I.
# 1233                                          Wood-R-E.
# 1234                   van-Vroonhoven-T-J.Molenaar-J-C.
# 1235                                        Bowman-B-H.
# 1236  Landau-L-I.Mellis-C-M.Phelan-P-D.Bristowe-B.Mc...
# 1237    Lieberman-J.Costea-N-V.Jakulis-V-J.Kaneshiro-W.
# 1238                    Bohles-H.Heid-H.Stehr-K.Fekl-W.
#
#                                                      TI  \
# 0     Pseudomonas aeruginosa infection in cystic fib...
# 1          Amylase content of mixed saliva in children.
# 2     A clinical study of the diagnosis of cystic fi...
# 3     A methodological study of the diagnosis of cys...
# 4     Proteolytic activity in duodenal juice in infa...
# 5     Pseudomonas aeruginosa infection in cystic fib...
# 6     Pseudomonas aeruginosa infection in cystic fib...
# 7     Epidemiological investigations of the respirat...
# 8     The occurrence of cystic fibrosis and celiac s...
# 9     Cystic fibrosis in a patient with Kartagener s...
# 10    Coexistent respiratory allergy and cystic fibr...
# 11    Letter: Silver-Russell dwarfism and cystic fib...
# 12    Cystic fibrosis in blacks in Washington, DC: i...
# 13    Present status of intrauterine diagnosis of ge...
# 14    Polypoid cervicitis in cystic fibrosis patient...
# 15    Ataxia-telangiectasia: chronic pneumonia, sinu...
# 16    Pulmonary involvement in adults with cystic fi...
# 17    Letter: Selective inhibition of phagocytic act...
# 18    Letter: Plasma arginine esterase activity in c...
# 19    The relative sensitivity of closing volume in ...
# 20    Bronchial asthma and allergic rhinitis associa...
# 21    Specific airway resistance from the perinatal ...
# 22    Human respiratory tract secretions.1. Mucous g...
# 23              Lung elastic recoil in cystic fibrosis.
# 24    Use of water vapor in the treatment of lower r...
# 25    Plasma arginine esterase activity in cystic fi...
# 26    Pulmonary physiotherapy in the pediatric age g...
# 27    Studies on neutron activation analysis for the...
# 28    Upper respiratory tract in cystic fibrosis.Ear...
# 29    Letter: Muscular performance and vitamin E in ...
# ...                                                 ...
# 1209  Detection of cystic fibrosis protein by isoele...
# 1210  Cystic fibrosis protein, a confirmed diagnosti...
# 1211  Serum factor in cystic fibrosis: correlation w...
# 1212  Intravenous linoleic acid supplementation in c...
# 1213  The chest roentgenogram in cystic fibrosis: a ...
# 1214  Negative effects of oral fatty acid supplement...
# 1215  Hypoelectrolytemia and metabolic alkalosis in ...
# 1216  Multifocal myocardial necrosis and fibrosis in...
# 1217                     Vitamin E: where do we stand?.
# 1218  Metabolic alkalosis in infants with cystic fib...
# 1219  An evaluation of the forced expiration techniq...
# 1220  A rapid procedure for the large scale purifica...
# 1221  Mitrochondrial NADH dehydrogenase in cystic fi...
# 1222  Cystic fibrosis: potential management through ...
# 1223  Changing patterns of genetic counseling in a c...
# 1224     Public-Health-Rep. 1979 Nov-Dec. 94(6). P 577.
# 1225        Cystic fibrosis--its surgical presentation.
# 1226  Chemotherapy of chronic infections with mucoid...
# 1227  Proteins in bronchial secretion of children wi...
# 1228  Proteins in bronchial secretion of children wi...
# 1229  Killing of fibroblasts by dexamethasone or dib...
# 1230  Premature senescence in cultured skin fibrobla...
# 1231   Cystic fibrosis in adolescents and young adults.
# 1232  Implications of cystic fibrosis for health ser...
# 1233  Cystic fibrosis: diagnosis, treatment, and pro...
# 1234  Distal splenorenal shunt for decompression of ...
# 1235  Cystic fibrosis: review of investigations of t...
# 1236  "Small airways disease" in children: no test i...
# 1237  Detection of a lectin in the blood of cystic f...
# 1238  Deficiencies of essential fatty acids and vita...
#
#                                                      SO  \
# 0        Acta-Paediatr-Scand. 1974 Nov. 63(6). P 843-8.
# 1       Acta-Paediatr-Scand. 1974 May. 63(3). P 389-92.
# 2        Acta-Paediatr-Scand. 1974 May. 63(3). P 411-7.
# 3       Acta-Paediatr-Scand. 1974 May. 63(3). P 405-10.
# 4        Acta-Paediatr-Scand. 1974 Nov. 63(6). P 805-8.
# 5     Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 6     Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 7     Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 8              Am-J-Dig-Dis. 1974 Feb. 19(2). P 149-55.
# 9            Am-J-Dis-Child. 1974 May. 127(5). P 746-7.
# 10           Am-J-Dis-Child. 1974 Sep. 128(3). P 355-9.
# 11           Am-J-Dis-Child. 1974 May. 127(5). P 760-1.
# 12            Am-J-Dis-Child. 1974 Jan. 127(1). P 64-7.
# 13    Am-J-Obstet-Gynecol. 1974 Mar 1. 118(5). P 718...
# 14    Am-J-Obstet-Gynecol. 1974 Apr 1. 118(7). P 971-4.
# 15    Am-J-Roentgenol-Radium-Ther-Nucl-Med. 1974 Feb...
# 16    Am-J-Roentgenol-Radium-Ther-Nucl-Med. 1974 Dec...
# 17          Am-Rev-Respir-Dis. 1974 Mar. 109(3). P 403.
# 18       Am-Rev-Respir-Dis. 1974 Sep. 110(3). P 368-70.
# 19       Am-Rev-Respir-Dis. 1974 May. 109(5). P 519-24.
# 20        Am-Rev-Respir-Dis. 1974 Dec. 110(6). P 812-3.
# 21        Am-Rev-Respir-Dis. 1974 Apr. 109(4). P 542-7.
# 22       Am-Rev-Respir-Dis. 1974 Oct. 110(4). P 428-41.
# 23        Am-Rev-Respir-Dis. 1974 Feb. 109(2). P 190-7.
# 24    Am-Rev-Respir-Dis. 1974 Dec. 110(6 Pt 2). P 10...
# 25      Am-Rev-Respir-Dis. 1974 Mar. 109(3). P 399-401.
# 26    Am-Rev-Respir-Dis. 1974 Dec. 110(6 Pt 2). P 13...
# 27       Ann-Clin-Lab-Sci. 1974 Nov-Dec. 4(6). P 413-9.
# 28            Arch-Dis-Child. 1974 Feb. 49(2). P 133-6.
# 29              Arch-Dis-Child. 1974 Mar. 49(3). P 247.
# ...                                                 ...
# 1209              Pediatr-Res. 1979 Sep. 13(9). P 1078.
# 1210           Pediatr-Res. 1979 Sep. 13(9). P 1079-81.
# 1211            Pediatr-Res. 1979 Jun. 13(6). P 729-32.
# 1212             Pediatrics. 1979 Aug. 64(2). P 207-13.
# 1213               Pediatrics. 1979 Jan. 63(1). P 24-9.
# 1214               Pediatrics. 1979 Jul. 64(1). P 50-2.
# 1215              Pediatrics. 1979 Apr. 63(4). P 580-3.
# 1216              Pediatrics. 1979 Mar. 63(3). P 361-8.
# 1217              Pediatrics. 1979 Jun. 63(6). P 933-5.
# 1218                Pediatrics. 1979 Sep. 64(3). P 389.
# 1219          Physiotherapy. 1979 Oct. 65(10). P 304-7.
# 1220                 Prep-Biochem. 1979. 9(1). P 15-31.
# 1221  Proc-Natl-Acad-Sci-USA. 1979 Jun. 76(6). P 297...
# 1222             Prog-Clin-Biol-Res. 1979. 34. P 111-7.
# 1223            Prog-Clin-Biol-Res. 1979. 34. P 119-32.
# 1224    CYSTIC-FIBROSIS: di.HETEROZYGOTE-DETECTION: mt.
# 1225             S-Afr-J-Surg. 1979 Jun. 17(2). P 51-7.
# 1226          Scand-J-Infect-Dis. 1979. 11(3). P 211-7.
# 1227       Scand-J-Respir-Dis. 1979 Apr. 60(2). P 63-8.
# 1228      Scand-J-Respir-Dis. 1979 Apr. 60(2). P 69-75.
# 1229         Science. 1979 Dec 14. 206(4424). P 1317-9.
# 1230         Science. 1979 Mar 23. 203(4386). P 1251-3.
# 1231             Scott-Med-J. 1979 Jul. 24(3). P 193-8.
# 1232  Soc-Sci-Med. 1979 Mar. 13A(2). P 147-50. (REVI...
# 1233  South-Med-J. 1979 Feb. 72(2). P 189-202. (REVI...
# 1234   Surg-Gynecol-Obstet. 1979 Oct. 149(4). P 559-60.
# 1235     Tex-Rep-Biol-Med. 1979. 38. P 47-53. (REVIEW).
# 1236                 Thorax. 1979 Apr. 34(2). P 217-23.
# 1237      Trans-Assoc-Am-Physicians. 1979. 92. P 121-9.
# 1238         Z-Ernahrungswiss. 1979 Jul. 18(2). P 81-7.
#
#                                                      MJ  \
# 0     CYSTIC-FIBROSIS: co.PSEUDOMONAS-AERUGINOSA: im...
# 1     SALIVA: en.AMYLASES: me.NUTRITION-DISORDERS: e...
# 2             CYSTIC-FIBROSIS: di.NAILS: an.SODIUM: an.
# 3             CYSTIC-FIBROSIS: di.NAILS: an.SODIUM: an.
# 4     DUODENUM: en.INTESTINAL-SECRETIONS: en.PEPTIDE...
# 5     B-LYMPHOCYTES: im.CYSTIC-FIBROSIS: im.IMMUNITY...
# 6     CYSTIC-FIBROSIS: im.IMMUNITY.PSEUDOMONAS-AERUG...
# 7     CYSTIC-FIBROSIS: mi.BACTERIA: ip.BACTERIA: ip....
# 8               CYSTIC-FIBROSIS: fg.CELIAC-DISEASE: fg.
# 9             CYSTIC-FIBROSIS: co.KARTAGENER-TRIAD: co.
# 10    CYSTIC-FIBROSIS: co.RESPIRATORY-HYPERSENSITIVI...
# 11    BONE-DISEASES-DEVELOPMENTAL: co.CYSTIC-FIBROSI...
# 12                    CYSTIC-FIBROSIS: oc.NEGROID-RACE.
# 13          HEREDITARY-DISEASES: di.PRENATAL-DIAGNOSIS.
# 14    CERVICITIS: ci.CERVIX-NEOPLASMS: ci.CONTRACEPT...
# 15    ADENOIDS: ra.ATAXIA-TELANGIECTASIA: co.PNEUMON...
# 16                        CYSTIC-FIBROSIS: ra.LUNG: ra.
# 17    CYSTIC-FIBROSIS: bl.MACROPHAGES: im.PHAGOCYTOS...
# 18                   CYSTIC-FIBROSIS: en.ESTERASES: bl.
# 19    ASTHMA: pp.CYSTIC-FIBROSIS: pp.LUNG: pp.RESPIR...
# 20    ALLERGENS.ASTHMA.CYSTIC-FIBROSIS: dt.DRUG-HYPE...
# 21    AGE-FACTORS.AIRWAY-RESISTANCE.CYSTIC-FIBROSIS:...
# 22    CYSTIC-FIBROSIS: me.GLYCOPROTEINS: se.HAY-FEVE...
# 23                 CYSTIC-FIBROSIS: pp.LUNG-COMPLIANCE.
# 24    RESPIRATORY-THERAPY.RESPIRATORY-TRACT-DISEASES...
# 25                   CYSTIC-FIBROSIS: en.ESTERASES: bl.
# 26                                    PHYSICAL-THERAPY.
# 27    ACTIVATION-ANALYSIS.CYSTIC-FIBROSIS: di.NAILS:...
# 28    CYSTIC-FIBROSIS: co.RESPIRATORY-TRACT-DISEASES...
# 29    CYSTIC-FIBROSIS: dt.MUSCLES: pp.MUSCULAR-DISEA...
# ...                                                 ...
# 1209  BLOOD-PROTEINS: an.CYSTIC-FIBROSIS: bl.ISOELEC...
# 1210  ALPHA-MACROGLOBULINS: me.BLOOD-PROTEINS: an.CY...
# 1211                  CYSTIC-FIBROSIS: bl.PEPTIDES: bl.
# 1212            CYSTIC-FIBROSIS: dh.LINOLEIC-ACIDS: tu.
# 1213                      CYSTIC-FIBROSIS: ra.LUNG: ra.
# 1214  CYSTIC-FIBROSIS: me.OILS: pd.SAFFLOWER-OIL: pd...
# 1215  ALKALOSIS: et.CYSTIC-FIBROSIS: co.WATER-ELECTR...
# 1216  ENDOMYOCARDIAL-FIBROSIS: pa.MYOCARDIUM: pa. CR...
# 1217  CHILD-NUTRITION.INFANT-NUTRITION-DISORDERS: dt...
# 1218                 ALKALOSIS: et.CYSTIC-FIBROSIS: co.
# 1219  BRONCHIAL-SPASM: th.CYSTIC-FIBROSIS: th.RESPIR...
# 1220  CATHEPSINS: ip.CYSTIC-FIBROSIS: en.PANCREATOPE...
# 1221  CYSTIC-FIBROSIS: en.MITOCHONDRIA: en. H-NADPH-...
# 1222           CYSTIC-FIBROSIS: th.EXOCRINE-GLANDS: se.
# 1223            CYSTIC-FIBROSIS: fg.GENETIC-COUNSELING.
# 1224                         CYSTIC-FIBROSIS: fg.HUMAN.
# 1225                               CYSTIC-FIBROSIS: co.
# 1226  ANTIBIOTICS: tu.CYSTIC-FIBROSIS: co.PNEUMONIA:...
# 1227  BRONCHI: se.IGA: se.IGA-SECRETORY.IGG: se.LACT...
# 1228  BRONCHI: se.IGA: se.IGA-SECRETORY.IGG: se.LACT...
# 1229  CYSTIC-FIBROSIS: di.DEXAMETHASONE: pd.DIBUTYRY...
# 1230                 CELL-SURVIVAL.CYSTIC-FIBROSIS: pa.
# 1231                               CYSTIC-FIBROSIS: di.
# 1232                               CYSTIC-FIBROSIS: px.
# 1233                               CYSTIC-FIBROSIS: th.
# 1234  CYSTIC-FIBROSIS: co.HYPERTENSION-PORTAL: su.RE...
# 1235            BLOOD-PROTEINS: ph.CYSTIC-FIBROSIS: pp.
# 1236                    ASTHMA: di.CYSTIC-FIBROSIS: di.
# 1237                   CYSTIC-FIBROSIS: bl.LECTINS: an.
# 1238  CYSTIC-FIBROSIS: pp.FATTY-ACIDS-ESSENTIAL: df....
#
#                                                      MN  \
# 0     ADOLESCENCE.BLOOD-PROTEINS: me.CHILD.CHILD-PRE...
# 1     INFANT.CHILD-PRESCHOOL.CHILD.ADOLESCENCE.HUMAN...
# 2     INFANT-NEWBORN.INFANT.CHILD-PRESCHOOL.CHILD.AD...
# 3     CHILD-PRESCHOOL.HUMAN.CYSTIC-FIBROSIS: me.ACTI...
# 4     ADULT.AGE-FACTORS.CASEINS: me.CELIAC-DISEASE: ...
# 5     ADOLESCENCE.ANTIBODIES-BACTERIAL.ANTIGENS-BACT...
# 6     ANTIBODIES-BACTERIAL.ANTIGENS-BACTERIAL.CYSTIC...
# 7     ADOLESCENCE.CHILD.CHILD-PRESCHOOL.CYSTIC-FIBRO...
# 8     ADULT.BIOPSY.CELIAC-DISEASE: co, fg.CHILD. TIC...
# 9     CASE-REPORT.CHLORIDES: an.HUMAN.INFANT.LUNG: r...
# 10    ADOLESCENCE.ADULT.AIRWAY-OBSTRUCTION: dt.ASTHM...
# 11             CASE-REPORT.CHILD.FEMALE.HUMAN.SYNDROME.
# 12    CYSTIC-FIBROSIS: co, di, fg.DISTRICT-OF-COLUMB...
# 13    ACID-PHOSPHATASE: me.ADRENAL-HYPERPLASIA-CONGE...
# 14    ADULT.BIOPSY.CERVICITIS: co.CERVIX-NEOPLASMS: ...
# 15    ATAXIA-TELANGIECTASIA: ra.CASE-REPORT.CHILD. T...
# 16    ADOLESCENCE.ADULT.ATELECTASIS: ra.CYSTIC-FIBRO...
# 17    CYSTIC-FIBROSIS: im.HUMAN.PSEUDOMONAS-AERUGINO...
# 18    ADULT.ARGININE.CHILD.CYSTIC-FIBROSIS: bl. CTRO...
# 19    ADOLESCENCE.ASTHMA: di.CHILD.HUMAN.OXYGEN: bl....
# 20    ADULT.CHILD.CYSTIC-FIBROSIS: im.ENVIRONMENTAL-...
# 21    ADOLESCENCE.ADULT.CHILD.CHILD-PRESCHOOL.CYSTIC...
# 22    ADULT.AMINO-ACIDS: an.AUTORADIOGRAPHY.CHILD. O...
# 23    ADOLESCENCE.ADULT.AIRWAY-OBSTRUCTION: et, pp.C...
# 24    AEROSOLS.AIR-MICROBIOLOGY.ANTISEPSIS.ASTHMA: t...
# 25    ACIDS.ADOLESCENCE.ADULT.ARGININE.CHLOROFORM. Y...
# 26    ACUTE-DISEASE.ASTHMA: th.BREATHING-EXERCISES.B...
# 27    ADULT.CHILD.HUMAN.NEUTRON-ACTIVATION-ANALYSIS:...
# 28    AGE-FACTORS.AUDIOMETRY.CHILD.CHILD-PRESCHOOL.D...
# 29    CLINICAL-TRIALS.CYSTIC-FIBROSIS: pp.HUMAN. CUL...
# ...                                                 ...
# 1209                                             HUMAN.
# 1210  CYSTIC-FIBROSIS: di, fg.GENETIC-SCREENING.HUMA...
# 1211  ADOLESCENCE.ADULT.ANIMAL.BIOLOGICAL-ASSAY.CARB...
# 1212  ARACHIDONIC-ACIDS: bl.BODY-HEIGHT.BODY-WEIGHT....
# 1213  CHILD.CYSTIC-FIBROSIS: pp.EVALUATION-STUDIES.H...
# 1214  ADOLESCENCE.CHILD.CHILD-PRESCHOOL.CYSTIC-FIBRO...
# 1215  CASE-REPORT.CHLORIDES: bl.FEMALE.HUMAN.HYPOKAL...
# 1216  ACUTE-DISEASE.CYSTIC-FIBROSIS: pa.FEMALE. RT-F...
# 1217  ADMINISTRATION-ORAL.ANEMIA-HEMOLYTIC: dt.BILIA...
# 1218  CARBON-DIOXIDE: bl.CHLORIDES: an.CYSTIC-FIBROS...
# 1219               ADOLESCENCE.ADULT.FEMALE.HUMAN.MALE.
# 1220  AMINO-ACID-SEQUENCE.BINDING-SITES.CHROMATOGRAP...
# 1221  CELLS-CULTURED.FIBROBLASTS: en.HUMAN. ROGEN-IO...
# 1222  ANIMAL.CATS.CYSTIC-FIBROSIS: pp.EXOCRINE-GLAND...
# 1223  ABORTION-LEGAL: px.ADULT.ATTITUDE-TO-HEALTH.CY...
# 1224  Development of a new test to detect carriers o...
# 1225  ADOLESCENCE.ADULT.BILIARY-TRACT-DISEASES: su.C...
# 1226  ADOLESCENCE.ADULT.CARBENICILLIN: tu.CHILD.CHIL...
# 1227  ADOLESCENCE.BRONCHI: im.BRONCHIECTASIS: di, im...
# 1228  ADOLESCENCE.BRONCHI: im.BRONCHIECTASIS: di, im...
# 1229  ADOLESCENCE.ADULT.CELL-DIVISION: de.CELL-SURVI...
# 1230  ADOLESCENCE.ADULT.AGING.CELL-DIVISION.CELLS-CU...
# 1231  ADOLESCENCE.ADULT.CHILD.CHILD-PRESCHOOL. TIC-F...
# 1232  ADAPTATION-PSYCHOLOGICAL.ADULT.CHILD.CYSTIC-FI...
# 1233  AEROSOLS.ANTIBIOTICS: tu.COUGH: et. TIC-FIBROS...
# 1234  ADOLESCENCE.CHILD.FEMALE.HUMAN.HYPERTENSION-PO...
# 1235  BIOLOGICAL-ASSAY.BODY-FLUIDS.CILIA: de.CYSTIC-...
# 1236  ADOLESCENCE.ADULT.ASTHMA: pp.CHILD.CYSTIC-FIBR...
# 1237  ANIMAL.CYSTIC-FIBROSIS: fg.DEXTRANS: pd.DOGS.G...
# 1238  ADOLESCENCE.BODY-HEIGHT.CHILD.CHILD-PRESCHOOL....
#
#                                                   AB/EX  \
# 0     The significance of Pseudomonas aeruginosa inf...
# 1     Salivary amylase levels were determined in nor...
# 2     This article reports on the possibility of usi...
# 3     Instrumental neutron activation analysis (INAA...
# 4     The capacity of duodenal juice to hydrolyse ca...
# 5     The influence of chronic Ps. aeruginosa infect...
# 6     The occurrence of Pseudomonas aeruginosa in th...
# 7     Seventy patients with cystic fibrosis treated ...
# 8     A family is presented in which celiac sprue an...
# 9     A patient exhibited the features of both Karta...
# 10    The prevalence of respiratory allergies and th...
# 11    Taussig et al reported a case of a 6-year-old ...
# 12    An intensive search for blacks with cystic fib...
# 13    Prenatal diagnosis of genetic disorders has re...
# 14    Three of the 4 women in a cystic fibrosis clin...
# 15    The syndrome of ataxia-telangiectasia is chara...
# 16    Cystic fibrosis is no longer rare in adults.Th...
# 17    As far as rabbit alveolar macrophages are conc...
# 18    We assayed the serum of a group of cystic fibr...
# 19    The ability to detect abnormalities of lung fu...
# 20    Five parents of children with cystic fibrosis ...
# 21    Airway resistance and lung volume were measure...
# 22    Ciliated nasal polyp epithelium from patients ...
# 23    The pressure-volume behavior of the lung was s...
# 24    Use of bland aerosols, particularly mist tents...
# 25    Plasma arginine esterase activity was measured...
# 26    In spite of the widespread clinical impression...
# 27    The present study points out the simplicity an...
# 28    An ear-nose-throat survey was carried out on 5...
# 29    Patients with cystic fibrosis have tocopherol ...
# ...                                                 ...
# 1209  Several cystic fibrosis research groups have i...
# 1210  The fact that alpha2-macroglobulin and cystic ...
# 1211  The relationship between the activity of the c...
# 1212  Ten children with CF in matched pairs were inf...
# 1213  A roentgenogram scoring system is presented th...
# 1214  Essential fatty acid supplementation with oral...
# 1215  The records of all children in the Tucson area...
# 1216  From a review of 2,000 autopsies of children, ...
# 1217  I propose that clinicians should have a genera...
# 1218  I have diagnosed six cystic fibrosis infants u...
# 1219  A criticism often levelled at the forced expir...
# 1220  A procedure is described which permits the rap...
# 1221  We have shown that skin fibroblast from patien...
# 1222  Ten years ago, we demonstrated that chronic ad...
# 1223  The change of life expectancy of cystic fibros...
# 1224  rosis was announced.The test involves the inte...
# 1225  In a series of 62 cases of cystic fibrosis pre...
# 1226  The bacteriological effect of chemotherapy aga...
# 1227  Bronchial secretions from 207 children sufferi...
# 1228  The concentration of immunoglobulins, lactofer...
# 1229  Assays based on the counting of total cells an...
# 1230  Cultured skin fibroblasts from subjects with c...
# 1231  With the early diagnosis of cystic fibrosis an...
# 1232  "Psychosocial" literature on cystic fibrosis (...
# 1233  This review is intended to present a brief sum...
# 1234  Apart from the sound physiologic basis for the...
# 1235  Recently, we found the cystic fibrosis mucocil...
# 1236  Tests claimed to detect small airway disease w...
# 1237  We theorize that cystic fibrosis may be a dise...
# 1238  In 25 children (13 male; 12 female) with cysti...
#
#                                                      RF  \
# 0     001 BELFRAGE SACTA MED SCAND SUPPL 173 5 963  ...
# 1     001 ANDERSEN DH J PEDIATR 30 564 947  BARBEZAT...
# 2     001 BOWEN HJM ADV ACTIVATION ANALYS1 101 969  ...
# 3     001 ANDERSEN GH TRANS AM NUCL SOC 1057 967  AN...
# 4     001 BERGSTROM K SCAND J GASTROENTEROL5 533 970...
# 5     001 AIUTI F INFECT IMMUN 8 110 973  AIUTI F CL...
# 6     001 BURNS MWLANCET 1 270 968  BURNS MWBR MED J...
# 7     001 BURNS MWLANCET 1 270 968  COWAN STMANUAL F...
# 8     001 HIDE DW ARCH DIS CHILD44 533 969  ANTONOWI...
# 9     001 KARTAGENER MBEITR KLIN TUBERK 83 489 933  ...
# 10    001 ABBOTT VCAN MED ASSOC J 64 419 951  BODIAN...
# 11             001 TAUSSIG LMAM J DIS CHILD 125 495 973
# 12    001 CARTER CO MOD PROBL PEDIATR 10 372 967  WR...
# 13    001 NADLER HL N ENGL J MED 282 596 970  GERBIE...
# 14    001 OPPENHEIMER EAAM J OBSTET GYNECOL108 673 9...
# 15    001 BODER E PEDIATRICS21 526 958  EISEN AHN EN...
# 16    002 CABANEL G J FRANC MED CHIR THORAC 21 245 9...
# 17    001 BOXERBAUM B AM REV RESPIR DIS108 777 973  ...
# 18    001 LIEBERMAN J AM REV RESPIR DIS109 399 974  ...
# 19    001 MCCARTHY DAM REV RESPIR DIS107 559 973  MC...
# 20    001 MATTHEWS LW IN: MANGOS JA303 973  DERBES V...
# 21    001 BRISCOE WAJ CLIN INVEST 371279 958  LLOYD ...
# 22    001 GREEN GMAM REV RESPIR DIS102 691 970  PROC...
# 23    001 COOK CD PEDIATRICS24 181 959  FEATHERBY EA...
# 24    001 COLE PJ LARYNGOL OTOL 67 449 953  SILVERMA...
# 25    001 RAO GJS SCIENCE177 610 972  CAUDILL M LANC...
# 26    001 DOYLE B PHYS THER REV 3924 959  ZAUSMER E ...
# 27    001 ANTONELLI M ARCH DIS CHILD44 218 969  BARN...
# 28    001 BROOKS DN INT AUDIOL 8 563 969  FORCUCCI R...
# 29    001 DARBY CWARCH DIS CHILD4872 973  LEVIN S PE...
# ...                                                 ...
# 1209  001 ALTLAND K HUMANGENETIK28 207 975  BEARN AG...
# 1210  001 ASHWELL G ADV ENZYM MOLEC BIOL4199 974  DA...
# 1211  001 ADSHEAD PCANN NY ACAD SCI253 192 975  ARAK...
# 1212  001 KUO PTJ PEDIATR 60 394 962  CAREN R J CLIN...
# 1213  001 HODSON CJ CLIN RADIOL 1354 962  SHWACHMAN ...
# 1214  001 ELLIOTT RBARCH DIS CHILD5076 975  ELLIOTT ...
# 1215  001 GOTTLIEB RP J PEDIATR 79 930 971  DI SANTA...
# 1216  001 WISSLER H HELV PAEDIATR ACTA SUPPL 1 1 3 9...
# 1217  001 MELHORN DKOHIO STATE MED J69 899 973  OSKI...
# 1218  001 BECKERMAN RCPEDIATRICS63 580 979  DI SANTA...
# 1219  001 ANONTHORAX14 286 959  COCHRANE GM BR MED J...
# 1220  001 JANOFF AAM J PATHOL 68 579 972  LAZARUS GS...
# 1221  001 NADLER HL IN: STANBURY JB 1683 978  DI SAN...
# 1222  001 MANGOS JA IN: ANDREOLI TE978  MANGOS JA J ...
# 1223  001 BOYLE IRJ PEDIATR 88 318 976  CARTER CO LA...
# 1224                                               None
# 1225  001 DI SANTAGNESE PAN ENGL J MED 2771287 967  ...
# 1226  001 ANDERSON EL ANTIMICROB AGENTS CHEMOTHER8 3...
# 1227  001$ADINOLFI MIMMUNOLOGY10 517 966  ALFORD RH ...
# 1228  001 ALFORD RH J IMMUNOL101 984 968  DEUSCHL H ...
# 1229  001 EPSTEIN JLPROC NAT ACAD SCI USA 745642 977...
# 1230  001 ANONGAP CONF REP TISS CULT APPR977  RAFF E...
# 1231  001 BOAT TF AM REV RESPIR DIS116 1 977  BOAT T...
# 1232  001 KRAMM ERPEDIATRICS28 135 961  POGUE REMINN...
# 1233  001 WOOD RE AM REV RESPIR DIS113 833 976  DI S...
# 1234  001 GALAMBOS JT N ENGL J MED 2951089 976  MAIL...
# 1235  001 ANDERSEN DH AM J DIS CHILD56 344 938  BARN...
# 1236  001 ANTHONISEN NR CLIN SCI35 495 968  ANTHONIS...
# 1237  001 MARCHI AG HELV PAEDIATR ACTA28 427 973  LI...
# 1238  001 ANONNUTR REV1713 959  BLANC WAPEDIATRICS22...
#
#                                                      CT
# 0     1 HOIBY N SCAND J RESPIR DIS5638 975 OIBY N AC...
# 1     1 ALHADEFF JA CLIN GENET1063 976 ASZLO AACTA P...
# 2     1 KOLLBERG HSCAND J CLIN LAB INVEST 3517 975 A...
# 3     1 HELLSING KSCAND J CLIN LAB INVEST 33 333 974...
# 4     1 BROCK JHIMMUNOLOGY32 207 977 CHMITZ J GASTRO...
# 5     1 HOIBY N ACTA PATH MICROBIOL SCAND (B) 82 551...
# 6     1 HOIBY N ACTA PATH MICROBIOL SCAND (B) 82 541...
# 7     1 HOIBY N ACTA PATH MICROBIOL SCAND (B) 82 559...
# 8              1 SAFWENBERG JTISSUE ANTIGENS 10 287 977
# 9     1 BOCHKOVA DN GENETIKA (SOVIET GENETICS)11 154...
# 10    1 HOLZEL APRACTITIONER 214 776 975 ARNER JO AR...
# 11    1 WOOD RE AM REV RESPIR DIS113 833 976 ARIETTI...
# 12                                                 None
# 13    1 HENRION R NOUV PRESSE MED32651 974 USS EGYNA...
# 14    1 GREENSTEIN JS CONTRACEPTION 11 105 975 OOD R...
# 15    1 SHACKELFORD GDAM J ROENTGENOL123 144 975 ALL...
# 16    1 WOOD RE AM REV RESPIR DIS113 833 976 UCK SR ...
# 17    1 HOIBY N ACTA PATH MICROBIOL SCAND (C) S262 3...
# 18    1 CHANGUS JEARCH PATHOL LAB MED100 7 976 ISANT...
# 19    1 GOTZ MPAEDIATR PAEDOL 10 466 975 ALL DR BULL...
# 20    1 BERGNER A PEDIATRICS55 814 975 ILAT L AM REV...
# 21    1 HATCH DJARCH DIS CHILD51 859 976 IBBERT MEJ ...
# 22    1 BOWMAN BH LIFE SCI191289 976 NONJ PEDIATR 88...
# 23    1 LANDAU LI AM REV RESPIR DIS111 725 975 APLET...
# 24    1 FEVRIER D SCHWEIZ MED WOCHENSCHR 105 903 975...
# 25    1 COBURN MD AM REV RESPIR DIS110 368 974 LTLAN...
# 26    1 PANG LM ANESTHESIOLOGY43 171 975 ELLINS RBJ ...
# 27                                                 None
# 28    1 WARNER JO PEDIATRE12 243 976 OS M J LARYNGOL...
# 29                                                 None
# ...                                                 ...
# 1209  1 TARNOKY ALJ ROY SOC MED 7373 980 EVIN GBHUM ...
# 1210  1 MANSON JC LANCET 1 330 980 ILSON GB LANCET 2...
# 1211  1 SORENSEN RU PEDIATR RES 1514 981 UTLAND J AM...
# 1212  1 KARP RJ CLIN CHEST MED 1 375 980 ARSONS HGPE...
# 1213  1 CHIPPS BE J PEDIATR 95 379 979 ESTER LA J PE...
# 1214  1 ROGIERS V PEDIATR RES 141088 980 LOYDSTILL J...
# 1215  1 BECKERMAN RCPEDIATRICS64 389 979 USSBAUM EAM...
# 1216  1 BACHMAN DSPEDIATRICS64 388 979 IMMERMANN AHE...
# 1217  1 HIGASHI A PEDIATR PHARMACOL1 129 980 EBOULAN...
# 1218  1 RAPAPORT RJ PEDIATR 98 768 981 ORSYTH JSSCOT...
# 1219  1 VANDERMEER JWMREV INFECT DIS 6 107 984 ATTIS...
# 1220  1 SENIOR RM J CLIN INVEST 66 859 980 CDONALD J...
# 1221  1 DAVIS PBPEDIATR RES 1483 980 EALE TWANN CLIN...
# 1222                                               None
# 1223                 1 PASSARGE EEUR J PEDIATR14354 984
# 1224                                               None
# 1225                                               None
# 1226  1 SCHIOTZ POACTA PATH MICROBIOL SCAND (C) S276...
# 1227  1 ZEBRAK JSCAND J RESPIR DIS6069 979 CHIOTZ PO...
# 1228  1 GAWEL J SCAND J RESPIR DIS6063 979 MBRUSO DR...
# 1229  1 SCANLIN TFCLIN CHEST MED 1 424 980 UCHWALD M...
# 1230  1 LAM LFH LIFE SCI242483 979 HAPIRO BLPROC NAT...
# 1231  1 JACOBS WH AM J GASTROENTEROL76 342 981 ACPHE...
# 1232           1 PLESS IBPEDIATR CLIN NORTH AM 3133 984
# 1233  1 HOLSCLAW DS CLIN CHEST MED 1 407 980 EED MD ...
# 1234  1 TABACHNIK NFSURG GYNECOL OBSTET152 837 981 O...
# 1235  1 HALLINAN FMED HYPOTHESES 7 793 981 HOMAS JM ...
# 1236  1 MANSMANN HC CLIN CHEST MED 1 339 980 HOMPSON...
# 1237  1 LIEBERMAN J J LAB CLIN MED97 646 981 EALE TW...
# 1238  1 CHO YWJ CLIN PHARMACOL21 224 981 OHLES HKLIN...
#
# [1239 rows x 11 columns]

# %%
# fazendo parse do arquivo de query
from operator import itemgetter
import numpy as np

cfquery = 'cfc/cfquery'
queryFile = []
weight = [1, 1, 1, 1] # peso, repectivamente, referente aos avaliadores: REW, REW colleagues, REW post-doctorates e JBW

def scoreCalc(weigth, v):
    values = [int(digit) for digit in v]
    weighted_avg = np.average(values, weights=weight)
    return weighted_avg

def insertQ(i, value, vector):
    if(len(vector) <= i):
        vector.insert(i,value)
    else:
        if(type(value) is list):
            vector[i].extend(value)
            vector[i].sort(key=itemgetter(1), reverse=True)
        elif(len(value)== 5):
            vector[i] = value
        elif(type(value) is str):
            vector[i] += value

def constructQueryVector(vector, line, cod):  
    if(cod == 'QN'):
        aux = list(line)
        k = ''
        k = str(k)
        for i in range(len(aux)):
            k = (str(k) + str(aux[i]))
        insertQ(0, k, vector)
        
    elif(cod == 'QU'):
        insertQ(1, line, vector)
        
    elif(cod == 'NR'):
        insertQ(2, str(int(line)), vector)
        
    elif(cod == 'RD'):
        v = line.split(' ')
        v1 = []
        ve = []
        for i, result in enumerate(v):
            if not(result):
                continue          
            v1.append(result)
            if(len(v1) == 2):
                v1[0] = int(v1[0])
                score = scoreCalc(weight, v1[1])
                v1[1] = score
                ve.append(v1)
                v1 = []
        
        insertQ(3, ve, vector)
    else:
        pass

def queryMatrix(file):
    matrix = []
    with open(file, 'r', encoding = 'iso-8859-1') as fp:
        vector = []
        line = fp.readline()
        cod = line[:2]
        constructQueryVector(vector, line[3:].strip(), cod)
        
        while line:
            line = fp.readline()
            
            if not((line[:2]).isspace()):
                cod = line[:2]
                line = line[3:]
        
            if(line.isspace()):
                matrix.append(vector)
                vector = []
            constructQueryVector(vector, line.strip(), cod)    
    
    fp.close()
    return matrix


queryFile.extend(queryMatrix(cfquery))
col= ['Number','Query','Relevants', 'Documents']
pd.DataFrame(queryFile[0:10], columns=col)
# Out:
#   Number                                              Query Relevants  \
# 0  00001  What are the effects of calcium on the physica...        34
# 1  00002  Can one distinguish between the effects of muc...         7
# 2  00003  How are salivary glycoproteins from CF patient...        43
# 3  00004  What is the lipid composition of CF respirator...         9
# 4  00005                              Is CF mucus abnormal?       131
# 5  00006  What is the effect of water or other therapeut...        24
# 6  00007  Are mucus glycoproteins degraded differently i...        28
# 7  00008  What histochemical differences have been descr...        22
# 8  00009  What is the association between liver disease ...        10
# 9  00010  What is the role of Vitamin E in the therapy o...        25
#
#                                            Documents
# 0  [[533, 2.0], [139, 1.75], [441, 1.75], [151, 1...
# 1  [[169, 0.25], [434, 0.5], [454, 0.25], [498, 0...
# 2  [[633, 2.0], [139, 1.75], [375, 1.75], [856, 1...
# 3  [[604, 2.0], [876, 2.0], [711, 1.75], [669, 0....
# 4  [[151, 2.0], [374, 2.0], [439, 2.0], [593, 2.0...
# 5  [[31, 2.0], [503, 1.25], [875, 1.0], [370, 0.5...
# 6  [[371, 1.75], [623, 1.5], [856, 1.25], [1064, ...
# 7  [[23, 1.5], [499, 1.5], [683, 1.5], [1125, 1.5...
# 8  [[414, 2.0], [165, 1.5], [794, 1.0], [1115, 0....
# 9  [[157, 2.0], [413, 2.0], [581, 2.0], [676, 1.7...

# %% [markdown]
# ## Passo 2 - Primeira indexação
#
# Depois de parsear os arquivos, agora é hora de indexar os dados. Ao invés de criar o código do zero, vamos usar o Whoosh, que é uma implementação em python inspirada no Lucene. A documentação pode ser encontrada em https://whoosh.readthedocs.io/en/latest/index.html.
#
# Nesta questão de indexação, temos que fazer algumas escolhas:
# * Como fazer o processo de tokenização?
# * Stemmizar ou não stemmizar, eis a questão...
# * Quais campos são úteis para indexação?
#
# Neste momento, você vai tomar suas decisões iniciais. A ideia é você testar, depois, outras soluções para verificar quais tiveram os melhores resultados, entendeu? Então não esqueça de documentar, aqui, qual a sua decisão inicial e depois ir explicando ao longo do notebook os experimentos que está fazendo.

# %%
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED,NUMERIC
from whoosh import index
import os, shutil


def createIndexDir(name, schema):
    if os.path.exists(name):
        shutil.rmtree(name)
    os.mkdir(name) # create an index directory
    ix = index.create_in(name, schema)
    return ix


#schema definition

schema = Schema(pn=NUMERIC(stored=True), #paper_number
                rn=NUMERIC(stored=True), #record_number
                ti=TEXT(stored=True), #title
                mj=TEXT(stored=True), #major_subjects
                mn=TEXT(stored=True), #minor_subjects
                ab=TEXT(stored=True), #abstract or extract
                )

def writeInIndex(indexName, schema):
    ix = createIndexDir(indexName, schema)
    ix = index.open_dir(indexName) #open an existing index object
    writer = ix.writer() #create a writer object to add documents to the index

    for doc in matrixTotal:
        writer.add_document(pn=doc[0], #add documents to the index
                            rn=doc[1],
                            ti=doc[4],
                            mj=doc[6],
                            mn=doc[7],
                            ab=doc[8]
                           )
    writer.commit()
    print(indexName + " criado com sucesso!")

    
    
    
writeInIndex("index", schema)
# Out:
# index criado com sucesso!

# %% [markdown]
# ## Passo 3 - Calculando as métricas de avaliação
#
# Para avaliar a tua decisão, vamos usar como métricas a precisão, recall e f-measure. Faça uma variação da precisão e recall como P@n e R@n, pois serão úteis para os gráficos que serão gerados.

# %% [markdown]
# ### 3.1 - Fazendo as queries

# %%
# normalizando as query para poder usar no whoosh
import spacy
from spacy.lang.pt.stop_words import STOP_WORDS
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')
nlp = spacy.load('en')


def norma(text):
    text = nlp(text.lower())
    termos = [token for token in text if not (token.is_stop or token.pos_ == 'PUNCT' or token.pos_ == 'PRON' or token.pos_ == 'CCONJ' or token.pos_ == 'DET')]
    texto = ''
    for term in termos:
        texto += ' ' + stemmer.stem(term.orth_) 
    return texto

# %%
from whoosh.qparser import *
from whoosh import scoring

queryTest = [] 

def makeQuery(query, schemaName):
    og = OrGroup.factory(0.9)
    parser = MultifieldParser(["ti", "ab", "mj", "mn"], schema=schemaName, group=og) 
    result=parser.parse(query)   
    return result
    
def storeQueryResult(queryTest, schemaName):    
    ix = index.open_dir("index") 

    for result in queryFile: 
        v = []
        v.append(result[0]) #question_number
        query = result[1] #query
        
        with ix.searcher() as searcher:
            result = makeQuery(query, schemaName)
            results=searcher.search(result, limit=None)#The Results object acts like a list of the matched documents.
            v.append(len(results)) 
            docs = []
            for doc in results:
                docs.append(int(doc.get('rn')))
            v.append(docs)
        
        queryTest.append(v)
    return queryTest

queryTest = storeQueryResult(queryTest, schema)

col= ['Query','Retrived','Documents']
pd.DataFrame(queryTest[0:10], columns = col)
# Out:
#    Query  Retrived                                          Documents
# 0  00001       481  [533, 302, 484, 139, 52, 950, 856, 1185, 741, ...
# 1  00002       619  [761, 592, 754, 1082, 614, 498, 452, 980, 1223...
# 2  00003       900  [633, 856, 1206, 959, 128, 218, 805, 500, 1171...
# 3  00004       465  [725, 1039, 715, 876, 604, 148, 928, 768, 25, ...
# 4  00005       389  [151, 499, 975, 754, 498, 265, 592, 481, 1064,...
# 5  00006       648  [31, 47, 976, 805, 496, 592, 593, 1104, 441, 6...
# 6  00007       956  [1064, 754, 856, 498, 265, 151, 975, 499, 633,...
# 7  00008       784  [439, 1145, 768, 269, 1030, 25, 956, 453, 743,...
# 8  00009       621  [165, 549, 545, 339, 720, 581, 870, 99, 863, 1...
# 9  00010       770  [1218, 581, 165, 438, 414, 878, 326, 676, 963,...

# %% [markdown]
# ### 3.2 - Análise

# %%
totalDocuments = set()

for query in queryFile:
    for doc in query[3]:
        totalDocuments.add(doc[0])

def getRelevant(line, n=None):
    relevant = set()
    for i,doc in enumerate(line[3]):
        relevant.add(doc[0])
        if((n != None) and (i+1 == n)):
            return relevant
    return relevant

def getRetrived(line, n=None):
    retrived = set()
    for i,doc in enumerate(line[2]):
        retrived.add(doc)
        if((n != None) and (i+1 == n)):
            return retrived
    return retrived
        
def getTruePositive(relevant, retrived):
    return relevant & retrived

def getFalsePositive(relevant, retrived):
    return retrived - getTruePositive(relevant, retrived)

def getTrueNegative(relevant, retrived):
    return totalDocuments - (relevant | retrived)

def getFalseNegative(relevant, retrived):
    return relevant - getTruePositive(relevant, retrived)

def getPrecision(relevant, retrived):
    tp = getTruePositive(relevant, retrived)
    #fp = getFalsePositive(relevant, retrived)
    tp_fp = len(retrived) # len(tp) + len(fp)
    if(tp_fp == 0):
        return 0
    return len(tp)/tp_fp

def getRecall(relevant, retrived): 
    tp = getTruePositive(relevant, retrived)
    #fn = getFalseNegative(relevant, retrived)
    tp_fn = len(relevant) # len(tp) + len(fn)
    if(tp_fn == 0):
        return 0
    return len(tp)/tp_fn

def getFMeasure(precision, recall):
    p_r = precision + recall
    if(p_r == 0):
        return 0
    return (2 * precision * recall)/p_r

def precisionR(retrived, relevant, N): 
    tp = getTruePositive(relevant, retrived)
    return len(tp)/N

analysisMatrix = []

def analysis(queryFile, queryTest):
    for i, query in enumerate(queryFile):
        qn = []
        qn.append(int(query[0]))
        
        relevant = getRelevant(query)
        qn.append(len(relevant))
        #relevantUntil5 = getRelevant(query, 5)
        #relevantUntil10 = getRelevant(query, 10)
 
        retrived = getRetrived(queryTest[i])
        qn.append(len(retrived))
        retrivedUntil5 = getRetrived(queryTest[i], 5)
        retrivedUntil10 = getRetrived(queryTest[i], 10)

        precision = getPrecision(relevant, retrived)
        precisionUntil5 = getPrecision(relevant, retrivedUntil5)
        precisionUntil10 = getPrecision(relevant, retrivedUntil10)
        qn.append(precision)
        qn.append(precisionUntil5)
        qn.append(precisionUntil10)
        
        recall = getRecall(relevant, retrived)
        recallUntil5 = getRecall(relevant, retrivedUntil5)
        recallUntil10 = getRecall(relevant, retrivedUntil10)
        qn.append(recall)
        qn.append(recallUntil5)
        qn.append(recallUntil10)
        
        fMeasure = getFMeasure(precision, recall)
        qn.append(fMeasure)
        
        analysisMatrix.append(qn)

        
analysis(queryFile, queryTest)
col = ['Query','Relevant', 'Retrived', 'Precision', 'P@5','P@10','Recall','R@5','R@10', 'F-Measure']
pd.DataFrame(analysisMatrix[0:10], columns=col)
# Out:
#    Query  Relevant  Retrived  Precision  P@5  P@10    Recall       R@5  \
# 0      1        34       481   0.051975  0.4   0.3  0.735294  0.058824
# 1      2         7       619   0.008078  0.2   0.2  0.714286  0.142857
# 2      3        43       900   0.043333  0.4   0.3  0.906977  0.046512
# 3      4         9       465   0.017204  0.4   0.2  0.888889  0.222222
# 4      5       131       389   0.169666  0.8   0.8  0.503817  0.030534
# 5      6        24       648   0.035494  0.4   0.5  0.958333  0.083333
# 6      7        28       956   0.025105  0.4   0.3  0.857143  0.071429
# 7      8        22       784   0.022959  0.2   0.2  0.818182  0.045455
# 8      9        10       621   0.014493  0.2   0.1  0.900000  0.100000
# 9     10        25       770   0.029870  0.4   0.4  0.920000  0.080000
#
#        R@10  F-Measure
# 0  0.088235   0.097087
# 1  0.285714   0.015974
# 2  0.069767   0.082715
# 3  0.222222   0.033755
# 4  0.061069   0.253846
# 5  0.208333   0.068452
# 6  0.107143   0.048780
# 7  0.090909   0.044665
# 8  0.100000   0.028526
# 9  0.160000   0.057862

# %% [markdown]
# # Passo 4 - Gráficos do experimento 1
#
# Apresentar agora os gráficos do teu experimento. Você deve gerar um gráfico PxR, como visto em sala. Para gerar gráficos, você pode usar o matplotlib. Se quiser usar outra biblioteca que ache mais fácil, sem problemas!

# %%
import matplotlib.pyplot as plt

def plotGraph(analysisMatrix, queryFile, queryTest):
    R = [] 
    P = []
    tam = len(analysisMatrix)

    for i in range(tam):
        n = i+1
        somaP = 0
        somaR = 0
        for j, query in enumerate(queryFile):
            relevant = getRelevant(query)
            retrivedN = getRetrived(queryTest[j], n) 
            somaP += getPrecision(relevant, retrivedN) #P@n
            somaR += getRecall(relevant, retrivedN) #R@n
        P.append((somaP/tam))
        R.append((somaR/tam))

    plt.title("gráfico PxR")
    plt.plot(P,R)
    plt.xlabel("Precision")
    plt.ylabel("Recall")
    plt.legend("legenda")
    plt.show()

    plt.title("gráfico PxN")
    plt.plot(range(1,tam +1), P)
    plt.xlabel("Quantidade de valores")
    plt.ylabel("Precision")
    #plt.legend(legend)
    plt.show()

    plt.title("gráfico RxN")
    plt.plot(range(1,tam +1),R)
    plt.xlabel("Quantidade de valores")
    plt.ylabel("Recall")
    #plt.legend(legend)
    plt.show()

plotGraph(analysisMatrix, queryFile, queryTest)

# %% [markdown]
# ## Passo 5 - Demais experimentos
#
# Agora você irá testar novas configurações de campos e configurações para tentar encontrar qual a que te dá melhores resultados. Mostrar, como um relatório, a evolução do trabalho. Ou seja, mostrar como o trabalho foi evoluindo para você alcançar o melhor resultado (quais modificações foram feitas, como cada modificação influenciou nas métricas, etc).

# %%
from whoosh.analysis import StemmingAnalyzer
from nltk.corpus import stopwords

sw = stopwords.words("english")
ana =  StemmingAnalyzer(stoplist=sw)

schema2 = Schema(pn=ID(stored=True), #paper_number
                rn=NUMERIC(stored=True), #record_number
                ti=TEXT(analyzer=ana,stored=True), #title
                mj=KEYWORD(stored=True, scorable=True), #major_subjects
                mn=KEYWORD(stored=True, scorable=True), #minor_subjects
                ab=TEXT(analyzer=ana,stored=True), #abstract or extract
                )
    

writeInIndex("index2", schema2) #creating second index
print("Segundo Index criado!")
# Out:
# Segundo Index criado!

# %%
queryTest2 = []
queryTest2 = storeQueryResult(queryTest2, schema)

analysis(queryFile, queryTest2)
col = ['Query','Relevant', 'Retrived', 'Precision', 'P@5','P@10','Recall','R@5','P@10', 'F-Measure']
pd.DataFrame(analysisMatrix[0:10], columns=col)
# Out:
#    Query  Relevant  Retrived  Precision  P@5  P@10    Recall  R@5      P@10  \
# 0      1        34       536   0.042910  0.2   0.2  0.676471  0.2  0.200000
# 1      2         7       532   0.009398  0.0   0.0  0.714286  0.0  0.000000
# 2      3        43       516   0.048450  0.2   0.1  0.581395  0.2  0.100000
# 3      4         9       369   0.016260  0.4   0.2  0.666667  0.4  0.222222
# 4      5       131       389   0.169666  0.2   0.2  0.503817  0.2  0.200000
# 5      6        24       604   0.036424  0.2   0.1  0.916667  0.2  0.100000
# 6      7        28       717   0.027894  0.2   0.1  0.714286  0.2  0.100000
# 7      8        22       372   0.018817  0.0   0.0  0.318182  0.0  0.000000
# 8      9        10       416   0.021635  0.4   0.3  0.900000  0.4  0.300000
# 9     10        25       534   0.033708  0.4   0.5  0.720000  0.4  0.500000
#
#    F-Measure
# 0   0.080702
# 1   0.018553
# 2   0.089445
# 3   0.031746
# 4   0.253846
# 5   0.070064
# 6   0.053691
# 7   0.035533
# 8   0.042254
# 9   0.064401

# %%
plotGraph(analysisMatrix, queryFile, queryTest2)

# %% [markdown]
# ## Passo 6 - Quantos resultados eu devo voltar para o usuário?
#
# Um dos problemas de sistemas de IR é determinar quantos resultados você deve retornar ao usuário. Uma forma de entender o comportamento do sistema e qual o corte ideal na lista resultante é através do uso de curvas ROC. Assim, plote a curva ROC do teu sistema e determine, através da análise da curva, qual o ponto ideal de corte para o teu sistema.

# %%
# códigos...
