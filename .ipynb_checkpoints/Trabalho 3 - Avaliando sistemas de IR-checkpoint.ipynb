# %% [markdown]
# # Trabalho 3: Avaliando sistemas de IR
#
# Neste trabalho, o aluno irá explorar o problema de otimização de sistemas de IR através da análise de métricas de avaliação populares para esse tipo de sistema.
#
# Para isso, vamos usar a base CFC (com artigos sobre fibrose cística), a qual encontra-se nesta pasta.
#
# Observação: a idéia aqui é usar o jupyter para mostrar a evolução dos teus experimentos. Então use ele adequadamente. Ou seja, não altere funções do começo para reexecutar algo que foi feito lá embaixo. Neste caso, sobreescreva a função lá embaixo. A leitura do notebook tem que ser feita sequencialmente para ficar fácil, ok?
#
#
# ## Passo 1 - Normalização
#
# Primeira coisa que você vai precisar fazer é ler os arquivos do CFC. Essa é uma parte meio braçal mesmo, mas não tem como escapar dela. Então você terá que criar funções que consigam ler cada arquivo do CFC e parsear eles.

# %%
#códigos...
import pandas as pd

FILES = ['cfc/cf74', 'cfc/cf75', 'cfc/cf76', 'cfc/cf77', 'cfc/cf78', 'cfc/cf79']

def constructMatrix(line):
    vector = []
    cod = line[:2]
    
    if (cod.isspace()): 
        pass
    
    elif(cod == 'PN'):
        vector.insert(0,line[3:].rstrip("\n"))
        
    elif(cod == 'RN'):
        vector.insert(1,line[3:].rstrip("\n"))
        
    elif(cod == 'AN'):
        vector.insert(2,line[3:].rstrip("\n"))
        
    elif(cod == 'AU'):
        vector.insert(3,line[3:].rstrip("\n"))       
    
    elif(cod == 'TI'):
        vector.insert(4,line[3:].rstrip("\n"))
        
    elif(cod == 'SO'):
        vector.insert(5,line[3:].rstrip("\n"))
        
    elif(cod == 'MJ'):
        vector.insert(6,line[3:].rstrip("\n"))
    
    elif(cod == 'MN'):
        vector.insert(7,line[3:].rstrip("\n"))
        
    elif((cod == 'AB') or (cod == 'EX')):
        vector.insert(8,line[3:].rstrip("\n"))
        
    elif(cod == 'RF'):
        vector.insert(9,line[3:].rstrip("\n"))
        
    elif(cod == 'CT'):
        vector.insert(10,line[3:].rstrip("\n"))
    else:
        pass
    
    return vector

#for file in FILES:
matrix = []

with open('cfc/cf74', 'r', encoding = 'iso-8859-1') as fp:
    line = fp.readline()
    vector = constructMatrix(line)
    while line:
        line = fp.readline()
        if((line == "\n") and (vector != [])):
            matrix.append(vector)
            vector = []
        vector.extend(constructMatrix(line))
    
    
fp.close()             
pd.DataFrame(matrix)
# Out:
#         0       1         2   \
# 0    74001  00001   75051687
# 1    74002  00002   74260154
# 2    74003  00003   74252221
# 3    74004  00004   74252220
# 4    74005  00005   75051680
# 5    74006  00006   75014083
# 6    74007  00007   75014084
# 7    74008  00008   75009735
# 8    74009  00009   74087894
# 9    74010  00010   74154352
# 10   74011  00011   75008123
# 11   74012  00012   74154356
# 12   74013  00013   74074555
# 13   74014  00014   74103902
# 14   74015  00015   74129630
# 15   74016  00016   74107099
# 16   74017  00017   75144214
# 17   74018  00018   74109137
# 18   74019  00019   75012012
# 19   74020  00020   74146275
# 20   74021  00021   75052992
# 21   74022  00022   74122409
# 22   74023  00023   75010757
# 29   Letter: Muscular performance and vitamin E in ...
# ..                                                 ...
# 137  An evaluation of differential methylation of r...
# 138  Purification and properties of the calcium-pre...
# 139  Erythrocyte transport function in cystic fibro...
# 140  Arginine esterase in cystic fibrosis of the pa...
# 141         Letter: Cystic fibrosis ciliary inhibitor.
# 142  The methylation of transfer and ribosomal ribo...
# 143  Helium flow-volume curves in the detection of ...
# 144  Intellectual development after severe malnutri...
# 145  Outpatient intravenous medications in the mana...
# 146  Letter: Rates and calcium concentrations of sw...
# 147  Severe respiratory disease in infants with cys...
# 148               Liver-spleen scanning in pediatrics.
# 149  Use of serum amylase isoenzymes in evaluation ...
# 150  The electron microscopic appearance of presecr...
# 151                         Gentamicin in paediatrics.
# 152                         Therapeutic special diets.
# 153  Defects in the cell cycle of fibroblasts obtai...
# 154  Quantitative assessment of regional ventilatio...
# 155  Endoscopic pancreatography: an analysis of the...
# 156                          Vitamin E: who needs it?.
# 157  Analysis of albumin in meconium for early dete...
# 158  Tobramycin treatment of pseudomonas aeruginosa...
# 159      The patterns of infection in cystic fibrosis.
# 160  Susceptibility of mucoid Pseudomonas aeruginos...
# 161  Some materials on the genetics of mucoviscidosis.
# 162  Abnormal thyroid function and response to iodi...
# 163  Whole cell heat-killed gram-negative bacilli v...
# 164  The determination of vitamin A and some aspect...
# 165  Histochemical observations on the pulmonary ma...
# 166                  HL-A antigens in cystic fibrosis.
#
#                                                     5   \
# 0       Acta-Paediatr-Scand. 1974 Nov. 63(6). P 843-8.
# 1      Acta-Paediatr-Scand. 1974 May. 63(3). P 389-92.
# 2       Acta-Paediatr-Scand. 1974 May. 63(3). P 411-7.
# 3      Acta-Paediatr-Scand. 1974 May. 63(3). P 405-10.
# 4       Acta-Paediatr-Scand. 1974 Nov. 63(6). P 805-8.
# 5    Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 6    Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 7    Acta-Pathol-Microbiol-Scand [B]. 1974 Aug. 82(...
# 8             Am-J-Dig-Dis. 1974 Feb. 19(2). P 149-55.
# 9           Am-J-Dis-Child. 1974 May. 127(5). P 746-7.
# 10          Am-J-Dis-Child. 1974 Sep. 128(3). P 355-9.
# 11          Am-J-Dis-Child. 1974 May. 127(5). P 760-1.
# 12           Am-J-Dis-Child. 1974 Jan. 127(1). P 64-7.
# 13   Am-J-Obstet-Gynecol. 1974 Mar 1. 118(5). P 718...
# 14   Am-J-Obstet-Gynecol. 1974 Apr 1. 118(7). P 971-4.
# 15   Am-J-Roentgenol-Radium-Ther-Nucl-Med. 1974 Feb...
# 16   Am-J-Roentgenol-Radium-Ther-Nucl-Med. 1974 Dec...
# 17         Am-Rev-Respir-Dis. 1974 Mar. 109(3). P 403.
# 18      Am-Rev-Respir-Dis. 1974 Sep. 110(3). P 368-70.
# 19      Am-Rev-Respir-Dis. 1974 May. 109(5). P 519-24.
# 20       Am-Rev-Respir-Dis. 1974 Dec. 110(6). P 812-3.
# 3        CYSTIC-FIBROSIS: di.  NAILS: an.  SODIUM: an.
# 4    DUODENUM: en.  INTESTINAL-SECRETIONS: en.  PEP...
# 5    B-LYMPHOCYTES: im.  CYSTIC-FIBROSIS: im.  IMMU...
# 6    CYSTIC-FIBROSIS: im.  IMMUNITY.  PSEUDOMONAS-A...
# 7    CYSTIC-FIBROSIS: mi.  BACTERIA: ip.  BACTERIA:...
# 8            CYSTIC-FIBROSIS: fg.  CELIAC-DISEASE: fg.
# 9          CYSTIC-FIBROSIS: co.  KARTAGENER-TRIAD: co.
# 10   CYSTIC-FIBROSIS: co.  RESPIRATORY-HYPERSENSITI...
# 11   BONE-DISEASES-DEVELOPMENTAL: co.  CYSTIC-FIBRO...
# 12                 CYSTIC-FIBROSIS: oc.  NEGROID-RACE.
# 13       HEREDITARY-DISEASES: di.  PRENATAL-DIAGNOSIS.
# 14   CERVICITIS: ci.  CERVIX-NEOPLASMS: ci.  CONTRA...
# 15   ADENOIDS: ra.  ATAXIA-TELANGIECTASIA: co.  PNE...
# 16                     CYSTIC-FIBROSIS: ra.  LUNG: ra.
# 17   CYSTIC-FIBROSIS: bl.  MACROPHAGES: im.  PHAGOC...
# 18                CYSTIC-FIBROSIS: en.  ESTERASES: bl.
# 19   ASTHMA: pp.  CYSTIC-FIBROSIS: pp.  LUNG: pp.  ...
# 20   ALLERGENS.  ASTHMA.  CYSTIC-FIBROSIS: dt.  DRU...
# 21   AGE-FACTORS.  AIRWAY-RESISTANCE.  CYSTIC-FIBRO...
# 22   CYSTIC-FIBROSIS: me.  GLYCOPROTEINS: se.  HAY-...
# 23              CYSTIC-FIBROSIS: pp.  LUNG-COMPLIANCE.
# 24   RESPIRATORY-THERAPY.  RESPIRATORY-TRACT-DISEAS...
# 25                CYSTIC-FIBROSIS: en.  ESTERASES: bl.
# 26                                   PHYSICAL-THERAPY.
# 27   ACTIVATION-ANALYSIS.  CYSTIC-FIBROSIS: di.  NA...
# 28   CYSTIC-FIBROSIS: co.  RESPIRATORY-TRACT-DISEAS...
# 29   CYSTIC-FIBROSIS: dt.  MUSCLES: pp.  MUSCULAR-D...
# ..                                                 ...
# 137                     CYSTIC-FIBROSIS: me.  RNA: me.
# 138  CYSTIC-FIBROSIS: me.  PHOSPHOPROTEINS: ip.  SA...
# 139  CELL-MEMBRANE-PERMEABILITY.  CYSTIC-FIBROSIS: ...
# 140               ESTERASES: bl.  CYSTIC-FIBROSIS: en.
# 141    CYSTIC-FIBROSIS: me.  CILIA: de.  PROTEINS: ip.
# 142  CYSTIC-FIBROSIS: me.  RNA-RIBOSOMAL: me.  RNA-...
# 143  AIRWAY-OBSTRUCTION: di.  CYSTIC-FIBROSIS: co. ...
# 144           CHILD-DEVELOPMENT.  NUTRITION-DISORDERS.
# 145  ANTIBIOTICS: ad.  CYSTIC-FIBROSIS: co.  INFUSI...
# 146     CALCIUM: an.  CYSTIC-FIBROSIS: me.  SWEAT: an.
# 147  CYSTIC-FIBROSIS: co.  RESPIRATORY-INSUFFICIENC...
# 148  BILIARY-TRACT-DISEASES: di.  HEPATOMA: di.  KI...
# 149  AMYLASES: bl.  CYSTIC-FIBROSIS: en.  ISOENZYME...
# 150  CYSTIC-FIBROSIS: pp.  GASTRIC-MUCOSA: se.  MUCUS.
# 151                                   GENTAMICINS: tu.
# 152                                      DIET-THERAPY.
# 153             CYSTIC-FIBROSIS: pa.  FIBROBLASTS: pa.
# 154        CYSTIC-FIBROSIS: pp.  RADIONUCLIDE-IMAGING.
# 155  CHOLANGIOGRAPHY.  ENDOSCOPY.  PANCREAS: ra.  P...
# 156  MALABSORPTION-SYNDROMES: co.  NUTRITION-DISORD...
# 157  MECONIUM: an.  ALBUMINS: an.  CYSTIC-FIBROSIS:...
# 158  AMINOGLYCOSIDES: tu.  ANTIBIOTICS: tu.  CYSTIC...
# 159  CYSTIC-FIBROSIS: co.  RESPIRATORY-TRACT-INFECT...
# 160  PSEUDOMONAS-AERUGINOSA: de.  GENTAMICINS: pd. ...
# 161                 CHROMOSOMES.  CYSTIC-FIBROSIS: fg.
# 162  CYSTIC-FIBROSIS: dt.  IODIDES: tu.  THYROID-GL...
# 163  BACTERIAL-INFECTIONS: pc.  BACTERIAL-VACCINES:...
# 164                                         VITAMIN-A.
# 165             CYSTIC-FIBROSIS: pa.  MACROPHAGES: cy.
# 166  CYSTIC-FIBROSIS: im.  HISTOCOMPATIBILITY-ANTIG...
#
#                                                     7   \
# 0    ADOLESCENCE.  BLOOD-PROTEINS: me.  CHILD.  CHI...
# 1    INFANT.  CHILD-PRESCHOOL.  CHILD.  ADOLESCENCE...
# 2    INFANT-NEWBORN.  INFANT.  CHILD-PRESCHOOL.  CH...
# 3    CHILD-PRESCHOOL.  HUMAN.  CYSTIC-FIBROSIS: me....
# 4    ADULT.  AGE-FACTORS.  CASEINS: me.  CELIAC-DIS...
# 5    ADOLESCENCE.  ANTIBODIES-BACTERIAL.  ANTIGENS-...
# 6    ANTIBODIES-BACTERIAL.  ANTIGENS-BACTERIAL.  CY...
# 7    ADOLESCENCE.  CHILD.  CHILD-PRESCHOOL.  CYSTIC...
# 8    ADULT.  BIOPSY.  CELIAC-DISEASE: co, fg.  CHIL...
# 9    CASE-REPORT.  CHLORIDES: an.  HUMAN.  INFANT. ...
# 10   ADOLESCENCE.  ADULT.  AIRWAY-OBSTRUCTION: dt. ...
# 11    CASE-REPORT.  CHILD.  FEMALE.  HUMAN.  SYNDROME.
# 12   CYSTIC-FIBROSIS: co, di, fg.  DISTRICT-OF-COLU...
# 13   ACID-PHOSPHATASE: me.  ADRENAL-HYPERPLASIA-CON...
# 14   ADULT.  BIOPSY.  CERVICITIS: co.  CERVIX-NEOPL...
# 15    ATAXIA-TELANGIECTASIA: ra.  CASE-REPORT.  CHILD.
# 16   ADOLESCENCE.  ADULT.  ATELECTASIS: ra.  CYSTIC...
# 159  INFANT.  CHILD-PRESCHOOL.  CHILD.  ADOLESCENCE...
# 160  HUMAN.  PSEUDOMONAS-AERUGINOSA: ip.  MICROBIAL...
# 161  ADULT.  CHILD.  CONSANGUINITY.  FEMALE.  GENES...
# 162  ADOLESCENCE.  ADULT.  CHILD.  CYSTIC-FIBROSIS:...
# 163  ANTIBODY-FORMATION.  BURNS: im.  CHILD.  CHILD...
# 164  ADOLESCENCE.  ADULT.  BIOLOGICAL-TRANSPORT.  C...
# 165  ACID-PHOSPHATASE: an.  ADOLESCENCE.  ASTHMA: p...
# 166  ABO-BLOOD-GROUP-SYSTEM: an.  ADOLESCENCE.  BLO...
#
#                                                     8   \
# 0    The significance of Pseudomonas aeruginosa inf...
# 1    Salivary amylase levels were determined in nor...
# 2    This article reports on the possibility of usi...
# 3    Instrumental neutron activation analysis (INAA...
# 4    The capacity of duodenal juice to hydrolyse ca...
# 5    The influence of chronic Ps. aeruginosa infect...
# 6    The occurrence of Pseudomonas aeruginosa in th...
# 7    Seventy patients with cystic fibrosis treated ...
# 8    A family is presented in which celiac sprue an...
# 9    A patient exhibited the features of both Karta...
# 10   The prevalence of respiratory allergies and th...
# 11   Taussig et al reported a case of a 6-year-old ...
# 12   An intensive search for blacks with cystic fib...
# 13   Prenatal diagnosis of genetic disorders has re...
# 14   Three of the 4 women in a cystic fibrosis clin...
# 15   The syndrome of ataxia-telangiectasia is chara...
# 16   Cystic fibrosis is no longer rare in adults.  ...
# 17   As far as rabbit alveolar macrophages are conc...
# 18   We assayed the serum of a group of cystic fibr...
# 19   The ability to detect abnormalities of lung fu...
# 20   Five parents of children with cystic fibrosis ...
# 21   Airway resistance and lung volume were measure...
# 22   Ciliated nasal polyp epithelium from patients ...
# 23   The pressure-volume behavior of the lung was s...
# 24   Use of bland aerosols, particularly mist tents...
# 25   Plasma arginine esterase activity was measured...
# 26   In spite of the widespread clinical impression...
# 27   The present study points out the simplicity an...
# 28   An ear-nose-throat survey was carried out on 5...
# 29   Patients with cystic fibrosis have tocopherol ...
# ..                                                 ...
# 137  No differences were found in the methylation o...
# 138  A calcium-precipitable protein (CaPP), previou...
# 139  ATPase activity and monovalent cation transpor...
# 140  Arginine esterase activity in chloroform-ellag...
# 141  The fact that amniotic cells from fetuses at h...
# 142  A comprehensive study of tRNA and 18 S and 28 ...
# 143  To assess small airway disease in cystic fibro...
# 144  Intellectual performance, sensory motor abilit...
# 145  The management of cystic fibrosis continues to...
# 146  The authors of the recent article which failed...
# 147  The diagnosis, management and prognosis of 17 ...
# 148  Liver-spleen scans on 254 children were review...
# 149  Amylase isoenzyme patterns were evaluated in s...
# 150  Gastric mucosal biopsies from eight new untrea...
# 151  Gentamicin is a broad-spectrum, bactericidal a...
# 152  The aim of a therapeutic diet is to provide a ...
# 153  This paper analyzes the cell cycle of cystic f...
# 154  Twenty-five children aged 8 months to 17 years...
# 155  The endoscopic pancreaticographic findings in ...
# 156  This section considers the significance of vit...
# 157  Albumin in meconium was quantitated by means o...
# 158  Tobramycin treatment of chronic pulmonary infe...
# 159  Thirty-five patients with cystic fibrosis (age...
# 160  To compare the in vitro susceptibility of muco...
# 161  The purpose of the present work was to study t...
# 162  It has been suggested that the development of ...
# 163  This preliminary clinical study is of the abil...
# 164  The author has attempted to evaluate some of t...
# 165  The pulmonary macrophages collected with bronc...
# 166  HL-A frequencies of 28 patients with cystic fi...
#
#                                                     9   \
# 0    001   BELFRAGE S            ACTA MED SCAND SUP...
# 1    001   ANDERSEN DH           J PEDIATR         ...
# 2    001   BOWEN HJM             ADV ACTIVATION ANA...
# 3    001   ANDERSEN GH           TRANS AM NUCL SOC ...
# 4    001   BERGSTROM K           SCAND J GASTROENTE...
# 5    001   AIUTI F               INFECT IMMUN      ...
# 6    001   BURNS MW              LANCET            ...
# 7    001   BURNS MW              LANCET            ...
# 8    001   HIDE DW               ARCH DIS CHILD    ...
# 9    001   KARTAGENER M          BEITR KLIN TUBERK ...
# 10   001   ABBOTT V              CAN MED ASSOC J   ...
# 11   001   TAUSSIG LM            AM J DIS CHILD    ...
# 12   001   CARTER CO             MOD PROBL PEDIATR ...
# 13   001   NADLER HL             N ENGL J MED      ...
# 14   001   OPPENHEIMER EA        AM J OBSTET GYNECO...
# 15   001   BODER E               PEDIATRICS        ...
# 16   002   CABANEL G             J FRANC MED CHIR T...
# 17   001   BOXERBAUM B           AM REV RESPIR DIS ...
# 18   001   LIEBERMAN J           AM REV RESPIR DIS ...
# 19   001   MCCARTHY D            AM REV RESPIR DIS ...
# 20   001   MATTHEWS LW           IN: MANGOS JA     ...
# 21   001   BRISCOE WA            J CLIN INVEST     ...
# 22   001   GREEN GM              AM REV RESPIR DIS ...
# 23   001   COOK CD               PEDIATRICS        ...
# 24   001   COLE P                J LARYNGOL OTOL   ...
# 25   001   RAO GJS               SCIENCE           ...
# 26   001   DOYLE B               PHYS THER REV     ...
# 27   001   ANTONELLI M           ARCH DIS CHILD    ...
# 28   001   BROOKS DN             INT AUDIOL        ...
# 29   001   DARBY CW              ARCH DIS CHILD    ...
# ..                                                 ...
# 137  001   DRASHER ML            SCIENCE           ...
# 138  001  ANTONOPOULOS CA       ACTA CHEM SCAND    ...
# 139  001   AMES BN               J BIOL CHEM       ...
# 140  001   BOWMAN BH             SCIENCE           ...
# 141  002   BARNETT DR            TEX REP BIOL MED  ...
# 142  001   BALTIMORE D           J MOL BIOL        ...
# 143  001   MELLINS RB            PEDIATRICS        ...
# 144  001   STOCH MB              ARCH DIS CHILD    ...
# 145  001   STERN RC              CLIN PEDIATR      ...
# 146  001   PAUNIER L             PEDIATRICS        ...
# 147  001   SHWACHMAN H           PEDIATRICS        ...
# 148  001   TEFFT M               AM J ROENTG RAD TH...
# 149  001   DI SANTAGNESE PA      IN: NELSON WE     ...
# 150  001   MANDEL ID             AM J DIS CHILD    ...
# 151  001  ABSTON S              J INFECT DIS SUPPL ...
# 152  001   ANDERSON CM           ARCH DIS CHILD    ...
# 153  001   DANES BS              J EXP MED         ...
# 154  001   LAMARRE A             PEDIATRICS        ...
# 155  001   BLUMGART LH           LANCET            ...
# 156  001   MELHORN DK            OHIO STATE MED J  ...
# 157  001   ANDERSEN GH           TRANS AM NUCL SOC ...
# 158  001   BLACK HR              ANTIMICROB AGENTS ...
# 159  001   ALLANSMITH M          J PEDIATR         ...
# 160  001   COX CE                MED CLIN NORTH AM ...
# 161  001   FANCONI G             WIEN MED WOCHENSCH...
# 162  001   BRAVERMAN LE          N ENGL J MED      ...
# 163  001   FINLAND M             JAMA              ...
# 164  001   ALVSAKER JO           BIOCHEM J         ...
# 165  001   BALLANTYNE B          J PHYSIOL (LOND)  ...
# 166  001   ASQUITH P             LANCET            ...
#
#                                                     10
# 0      1   HOIBY N               SCAND J RESPIR DIS...
# 1      1   ALHADEFF JA           CLIN GENET        ...
# 2      1   KOLLBERG H            SCAND J CLIN LAB I...
# 3      1   HELLSING K            SCAND J CLIN LAB I...
# 4      1   BROCK JH              IMMUNOLOGY        ...
# 5      1   HOIBY N               ACTA PATH MICROBIO...
# 6      1   HOIBY N               ACTA PATH MICROBIO...
# 7      1   HOIBY N               ACTA PATH MICROBIO...
# 8      1   SAFWENBERG J          TISSUE ANTIGENS   ...
# 9      1   BOCHKOVA DN           GENETIKA (SOVIET G...
# 10     1   HOLZEL A              PRACTITIONER      ...
# 11     1   WOOD RE               AM REV RESPIR DIS ...
# 12                                                None
# 13     1   HENRION R             NOUV PRESSE MED   ...
# 14     1   GREENSTEIN JS         CONTRACEPTION     ...
# 15     1   SHACKELFORD GD        AM J ROENTGENOL   ...
# 16     1   WOOD RE               AM REV RESPIR DIS ...
# 17     1   HOIBY N               ACTA PATH MICROBIO...
# 18     1   CHANGUS JE            ARCH PATHOL LAB ME...
# 19     1   GOTZ M                PAEDIATR PAEDOL   ...
# 20     1   BERGNER A             PEDIATRICS        ...
# 21     1   HATCH DJ              ARCH DIS CHILD    ...
# 22     1   BOWMAN BH             LIFE SCI          ...
# 23     1   LANDAU LI             AM REV RESPIR DIS ...
# 24     1   FEVRIER D             SCHWEIZ MED WOCHEN...
# 25     1   COBURN MD             AM REV RESPIR DIS ...
# 26     1   PANG LM               ANESTHESIOLOGY    ...
# 27                                                None
# 28     1   WARNER JO             PEDIATRE          ...
# 29                                                None
# ..                                                 ...
# 137    1   HODES ME              PEDIATR RES       ...
# 138    1   BENNICK A             BIOCHEM J         ...
# 139    1   COLE CH               PEDIATR RES       ...
# 140    1   RAO GJS               PEDIATR RES       ...
# 141    1   WILSON GB             PEDIATR RES       ...
# 142    1   BOLTON WE             TEX REP BIOL MED  ...
# 143    1   LANDAU LI             AM REV RESPIR DIS ...
# 144    1   ELLIS CE              J PEDIATR         ...
# 145    1   DAVID S               PEDIATRICS        ...
# 146                                               None
# 147    1   SHWACHMAN H           PEDIATR CLIN NORTH...
# 148    1   WALKER WA             PEDIATR CLIN NORTH...
# 149    1   ROSS ME               ANN INTERN MED    ...
# 150    1   WOOD RE               AM REV RESPIR DIS ...
# 151    1   MCALLISTER TA         SCOTT MED J       ...
# 152                                               None
# 153    1   GOSPODAROWICZ D       J CELL BIOL       ...
# 154    1   SECKERWALKER RH       RESPIRATION       ...
# 155    1   KASUGAI T             DIGESTION         ...
# 156                                               None
# 157    1   RAINE DN              LANCET            ...
# 158    1   HOIBY N               SCAND J RESPIR DIS...
# 159    1   MITCHELLHEGGS P       Q J MED           ...
# 160    1   HOIBY N               ACTA PATH MICROBIO...
# 161                                               None
# 162    1   OSATHANONDH R         J CLIN ENDOCRINOL ...
# 163    1   STANISLAVSKY ES       ZH MIKROBIO EPIDEM...
# 164    1   NATANSON AO           VOPR MED KHIM     ...
# 165    1   SOMAYAJULU RSN        FOLIA HISTOCHEM CY...
# 166    1   WOOD RE               AM REV RESPIR DIS ...
#
# [167 rows x 11 columns]

# %% [markdown]
# ## Passo 2 - Primeira indexação
#
# Depois de parsear os arquivos, agora é hora de indexar os dados. Ao invés de criar o código do zero, vamos usar o Whoosh, que é uma implementação em python inspirada no Lucene. A documentação pode ser encontrada em https://whoosh.readthedocs.io/en/latest/index.html.
#
# Nesta questão de indexação, temos que fazer algumas escolhas:
# * Como fazer o processo de tokenização?
# * Stemmizar ou não stemmizar, eis a questão...
# * Quais campos são úteis para indexação?
#
# Neste momento, você vai tomar suas decisões iniciais. A ideia é você testar, depois, outras soluções para verificar quais tiveram os melhores resultados, entendeu? Então não esqueça de documentar, aqui, qual a sua decisão inicial e depois ir explicando ao longo do notebook os experimentos que está fazendo.

# %%
#códigos...

# %% [markdown]
# ## Passo 3 - Calculando as métricas de avaliação
#
# Para avaliar a tua decisão, vamos usar como métricas a precisão, recall e f-measure. Faça uma variação da precisão e recall como P@n e R@n, pois serão úteis para os gráficos que serão gerados.

# %%
#códigos...

# %% [markdown]
# ## Passo 4 - Gráficos do experimento 1
#
# Apresentar agora os gráficos do teu experimento. Você deve gerar um gráfico PxR, como visto em sala. Para gerar gráficos, você pode usar o matplotlib. Se quiser usar outra biblioteca que ache mais fácil, sem problemas!

# %%
# códigos...

# %% [markdown]
# ## Passo 5 - Demais experimentos
#
# Agora você irá testar novas configurações de campos e configurações para tentar encontrar qual a que te dá melhores resultados. Mostrar, como um relatório, a evolução do trabalho. Ou seja, mostrar como o trabalho foi evoluindo para você alcançar o melhor resultado (quais modificações foram feitas, como cada modificação influenciou nas métricas, etc).

# %%
# códigos...

# %% [markdown]
# ## Passo 6 - Quantos resultados eu devo voltar para o usuário?
#
# Um dos problemas de sistemas de IR é determinar quantos resultados você deve retornar ao usuário. Uma forma de entender o comportamento do sistema e qual o corte ideal na lista resultante é através do uso de curvas ROC. Assim, plote a curva ROC do teu sistema e determine, através da análise da curva, qual o ponto ideal de corte para o teu sistema.

# %%
# códigos...
